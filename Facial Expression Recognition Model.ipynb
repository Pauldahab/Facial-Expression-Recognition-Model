# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import cv2
import numpy as np

# %%
model= torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in C:\Users\LENOVO/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-3-13 Python-3.9.13 torch-1.13.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
img=os.path.join('data','train','images','250880f8-bf49-11ed-b683-342eb7af0360.jpg')
result=model(img)
result
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 480x640 1 person
# Speed: 181.8ms pre-process, 554.0ms inference, 72.2ms NMS per image at shape (1, 3, 480, 640)

# %%
import cv2
import os
import uuid
import time

# %%
IMAGES_PATH=os.path.join('facedata','images')
number_images=30
labels=['awake','drowsy']

# %%
cap=cv2.VideoCapture(0)
for label in labels:
    print('collecting images for {}'.format(label))
    time.sleep(5)
    for img_num in range(number_images):
        print('Collecting images for {} , image number {}'.format(label,img_num))
        ret,frame=cap.read()
        imgname=os.path.join(IMAGES_PATH,label+'.'+str(uuid.uuid1())+'.jpg')
        cv2.imwrite(imgname,frame)
        cv2.imshow('frame',frame)
        time.sleep(2)
        if cv2.waitKey(10)& 0xFF==ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# collecting images for awake
# ...
# collecting images for drowsy
# ...

# %%
# !labelImg
# Out:
# Cancel creation.
# Cancel creation.
# Cancel creation.
# Image:C:\Users\LENOVO\facedata\images\awake.9a10c16a-c10b-11ed-b217-342eb7af0360.jpg -> Annotation:C:/Users/LENOVO/facedata/labels\awake.9a10c16a-c10b-11ed-b217-342eb7af0360.txt
# Image:C:\Users\LENOVO\facedata\images\awake.9b46827b-c10b-11ed-b32d-342eb7af0360.jpg -> Annotation:C:/Users/LENOVO/facedata/labels\awake.9b46827b-c10b-11ed-b32d-342eb7af0360.txt
# Cancel creation.
# Image:C:\Users\LENOVO\facedata\images\awake.9c7f1aaa-c10b-11ed-9172-342eb7af0360.jpg -> Annotation:C:/Users/LENOVO/facedata/labels\awake.9c7f1aaa-c10b-11ed-9172-342eb7af0360.txt
# Image:C:\Users\LENOVO\facedata\images\awake.9db97b98-c10b-11ed-9ca2-342eb7af0360.jpg -> Annotation:C:/Users/LENOVO/facedata/labels\awake.9db97b98-c10b-11ed-9ca2-342eb7af0360.txt
# Cancel creation.
# Image:C:\Users\LENOVO\facedata\images\awake.9eef80d6-c10b-11ed-b084-342eb7af0360.jpg -> Annotation:C:/Users/LENOVO/facedata/labels\awake.9eef80d6-c10b-11ed-b084-342eb7af0360.txt
# ...

# %%
import tensorflow as tf
import json
import numpy as np
from matplotlib import pyplot as plt

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 5 --data dataset.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-120-g3e55763 Python-3.9.13 torch-1.13.1 CPU
#
# ...

# %%
model= torch.hub.load('ultralytics/yolov5','custom',path='yolov5/runs/train/exp3/weigths/last.pt',force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\LENOVO/.cache\torch\hub\master.zip
# YOLOv5  2023-3-13 Python-3.9.13 torch-1.13.1+cpu CPU
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.cache\torch\hub\ultralytics_yolov5_master\hubconf.py:49, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      48 try:
# ---> 49     model = DetectMultiBackend(path, device=device, fuse=autoshape)  # detection model
#      50     if autoshape:
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:344, in DetectMultiBackend.__init__(self, weights, device, dnn, data, fp16, fuse)
#     343 if pt:  # PyTorch
# --> 344     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#     345     stride = max(int(model.stride.max()), 32)  # model stride
#
# ...

# %%
cap=cv2.VideoCapture(0)
for label in labels:
        ret,frame=cap.read()
        results=model(frame)
        cv2.imshow('frame',np.squeeze(results.render()))
        if cv2.waitKey(10)& 0xFF==ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
